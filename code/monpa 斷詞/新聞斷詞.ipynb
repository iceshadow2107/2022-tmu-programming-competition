# %%
import pandas as pd
import monpa
# Out:
# +---------------------------------------------------------------------+
#   Welcome to MONPA: Multi-Objective NER POS Annotator for Chinese
# +---------------------------------------------------------------------+
# 已找到 model檔。Found model file.

# %% [markdown]
# ## 自主健康管理 中時＋自由

# %% [markdown]
# ### 檔案讀入-中時

# %%
selfm_china = pd.read_csv("/Users/lilywang/Library/CloudStorage/OneDrive-臺北醫學大學/畢業專題/資料與程式碼/Reader Emotion(情感分析資料)/中時＋自由/自主健康管理/中時/自主健康管理.csv", encoding = 'utf-8')
selfm_china.head()

# %% [markdown]
# ### 檔案讀入-自由

# %%
selfm_free = pd.read_csv("/Users/lilywang/Library/CloudStorage/OneDrive-臺北醫學大學/畢業專題/資料與程式碼/Reader Emotion(情感分析資料)/中時＋自由/自主健康管理/自由/自主健康管理.csv", encoding = 'utf-8')
selfm_free.head()

# %% [markdown]
# ### 贅字與標點符號去除

# %%
stop_words_file  = "/Users/lilywang/Library/CloudStorage/OneDrive-臺北醫學大學/畢業專題/資料與程式碼/Reader Emotion(情感分析資料)/中時＋自由/stopword_chinese.txt"

# %% [markdown]
# ### 斷詞-中時與自由

# %%
from monpa import utils

selfm_china.fillna('',inplace=True)

for i in range(len(selfm_china)):
    result = []
    for item in utils.short_sentence(selfm_china.loc[i,'TITLE'] + selfm_china.loc[i,'CONTENT']):
        if item:
            result.append(monpa.cut(item))

    tmp_result =""
    for k in range(len(result)):
        tmp_result += " ".join(result[k])
    selfm_china.loc[i,'cut_text'] = tmp_result
    print('i=:',i)
    #break

selfm_china.head(), len(selfm_china)

# %%
from monpa import utils

selfm_free.fillna('',inplace=True)

for i in range(len(selfm_free)):
    result = []
    for item in utils.short_sentence(selfm_free.loc[i,'TITLE'] + selfm_free.loc[i,'CONTENT']):
        if item:
            result.append(monpa.cut(item))

    tmp_result =""
    for k in range(len(result)):
        tmp_result += " ".join(result[k])
    selfm_free.loc[i,'cut_text'] = tmp_result
    print('i=:',i)
    #break

selfm_free.head(), len(selfm_free)

# %% [markdown]
# ### 去除贅字與標點符號

# %%
def clean_seg_list(seg_list):
    stop_words = [line.strip() for line in open
                  (stop_words_file, encoding="utf-8").readlines()]
    return [seg for seg in seg_list if seg[0] not in stop_words]

# %%
def get_cleaned_seg(df):    
    cleaned = []
    for line in df['cut_text']:
        items = line.split()
        item = ' '.join(clean_seg_list(items))
        cleaned.append(item)
    df['cleaned_text'] = cleaned
    
    return df

# %% [markdown]
# ### 看最後整理出來的結果

# %%
selfm_china = get_cleaned_seg(selfm_china)
selfm_china.head(), len(selfm_china)

# %%
selfm_free = get_cleaned_seg(selfm_free)
selfm_free.head(), len(selfm_free)

# %% [markdown]
# ## 轉換index成類別

# %% [markdown]
# ### 中時

# %%
selfm_china = selfm_china.rename_axis('index').reset_index()
selfm_china

# %%
selfm_china = selfm_china[['index', 'TITLE', 'cleaned_text', 'FROM', 'TIME']]
selfm_china.columns = ['CATEGORY', 'TITLE', 'cleaned_text', 'FROM', 'TIME']
selfm_china

# %% [markdown]
# ### 中時資料存成csv檔

# %%
selfm_china.to_csv("/Users/lilywang/Library/CloudStorage/OneDrive-臺北醫學大學/畢業專題/資料與程式碼/Reader Emotion(情感分析資料)/中時＋自由/自主健康管理/中時/自主健康管理_cleaned.csv", header=True, index=False, encoding="utf-8")

# %% [markdown]
# ### 自由

# %%
selfm_free = selfm_free.rename_axis('index').reset_index()
selfm_free.head()

# %% [markdown]
# ### 自由資料存成csv檔

# %%
selfm_free = selfm_free[['index', 'TITLE', 'cleaned_text', 'FROM', 'TIME']]
selfm_free.columns = ['CATEGORY', 'TITLE', 'cleaned_text', 'FROM', 'TIME']

selfm_free.head()

# %%
selfm_free.to_csv("/Users/lilywang/Library/CloudStorage/OneDrive-臺北醫學大學/畢業專題/資料與程式碼/Reader Emotion(情感分析資料)/中時＋自由/自主健康管理/自由/自主健康管理_cleaned.csv", header=True, index=False, encoding="utf-8")

# %% [markdown]
# ## 自主健康監測 中時

# %%
selft_china = pd.read_csv("/Users/lilywang/Library/CloudStorage/OneDrive-臺北醫學大學/畢業專題/資料與程式碼/Reader Emotion(情感分析資料)/中時＋自由/自我健康檢測/中時/自我健康監測.csv", encoding = 'utf-8')
selft_china.head()

# %%
from monpa import utils

selft_china.fillna('',inplace=True)

for i in range(len(selft_china)):
    result = []
    for item in utils.short_sentence(selft_china.loc[i,'TITLE'] + selft_china.loc[i,'CONTENT']):
        if item:
            result.append(monpa.cut(item))

    tmp_result =""
    for k in range(len(result)):
        tmp_result += " ".join(result[k])
    selft_china.loc[i,'cut_text'] = tmp_result
    print('i=:',i)
    #break

selft_china.head(), len(selft_china)

# %%
selft_china = get_cleaned_seg(selft_china)
selft_china.head(), len(selft_china)

# %%
selft_china = selft_china.rename_axis('index').reset_index()
selft_china

# %%
selft_china = selft_china[['index', 'TITLE', 'cleaned_text', 'FROM', 'TIME']]
selft_china.columns = ['CATEGORY', 'TITLE', 'cleaned_text', 'FROM', 'TIME']
selft_china

# %%
selft_china.to_csv("/Users/lilywang/Library/CloudStorage/OneDrive-臺北醫學大學/畢業專題/資料與程式碼/Reader Emotion(情感分析資料)/中時＋自由/自我健康檢測/中時/自我健康監測_cleaned.csv", header=True, index=False, encoding="utf-8")

# %% [markdown]
# ## 自我健康監測 自由

# %%
selft_free = pd.read_csv("/Users/lilywang/Library/CloudStorage/OneDrive-臺北醫學大學/畢業專題/資料與程式碼/Reader Emotion(情感分析資料)/中時＋自由/自我健康檢測/自由/自我健康監測.csv", encoding = 'utf-8')
selft_free.head()

# %%
from monpa import utils

selft_free.fillna('',inplace=True)

for i in range(len(selft_free)):
    result = []
    for item in utils.short_sentence(selft_free.loc[i,'TITLE'] + selft_free.loc[i,'CONTENT']):
        if item:
            result.append(monpa.cut(item))

    tmp_result =""
    for k in range(len(result)):
        tmp_result += " ".join(result[k])
    selft_free.loc[i,'cut_text'] = tmp_result
    print('i=:',i)
    #break

selft_free.head(), len(selft_free)

# %%
selft_free = get_cleaned_seg(selft_free)
selft_free.head(), len(selft_free)

# %%
selft_free = selft_free.rename_axis('index').reset_index()
selft_free.head()

# %%
selft_free = selft_free[['index', 'TITLE', 'cleaned_text', 'FROM', 'TIME']]
selft_free.columns = ['CATEGORY', 'TITLE', 'cleaned_text', 'FROM', 'TIME']

selft_free.head()

# %%
selft_free.to_csv("/Users/lilywang/Library/CloudStorage/OneDrive-臺北醫學大學/畢業專題/資料與程式碼/Reader Emotion(情感分析資料)/中時＋自由/自我健康檢測/自由/自我健康監測_cleaned.csv", header=True, index=False, encoding="utf-8")

# %% [markdown]
# ## 快篩試劑-中時

# %%
fastt_china = pd.read_csv("/Users/lilywang/Library/CloudStorage/OneDrive-臺北醫學大學/畢業專題/資料與程式碼/Reader Emotion(情感分析資料)/中時＋自由/快篩試劑/中時/快篩試劑.csv", encoding = 'utf-8')
fastt_china.head()

# %%
from monpa import utils

fastt_china.fillna('',inplace=True)

for i in range(len(fastt_china)):
    result = []
    for item in utils.short_sentence(fastt_china.loc[i,'TITLE'] + fastt_china.loc[i,'CONTENT']):
        if item:
            result.append(monpa.cut(item))

    tmp_result =""
    for k in range(len(result)):
        tmp_result += " ".join(result[k])
    fastt_china.loc[i,'cut_text'] = tmp_result
    print('i=:',i)
    #break

fastt_china.head(), len(fastt_china)

# %%
fastt_china = get_cleaned_seg(fastt_china)
fastt_china.head(), len(fastt_china)

# %%
fastt_china = fastt_china.rename_axis('index').reset_index()
fastt_china

# %%
fastt_china = fastt_china[['index', 'TITLE', 'cleaned_text', 'FROM', 'TIME']]
fastt_china.columns = ['CATEGORY', 'TITLE', 'cleaned_text', 'FROM', 'TIME']
fastt_china

# %%
fastt_china.to_csv("/Users/lilywang/Library/CloudStorage/OneDrive-臺北醫學大學/畢業專題/資料與程式碼/Reader Emotion(情感分析資料)/中時＋自由/快篩試劑/中時/快篩試劑_cleaned.csv", header=True, index=False, encoding="utf-8")

# %% [markdown]
# ## 快篩試劑-自由

# %%
fastt_free = pd.read_csv("/Users/lilywang/Library/CloudStorage/OneDrive-臺北醫學大學/畢業專題/資料與程式碼/Reader Emotion(情感分析資料)/中時＋自由/快篩試劑/自由/快篩試劑.csv", encoding = 'utf-8')
fastt_free.head()

# %%
from monpa import utils

fastt_free.fillna('',inplace=True)

for i in range(len(fastt_free)):
    result = []
    for item in utils.short_sentence(fastt_free.loc[i,'TITLE'] + fastt_free.loc[i,'CONTENT']):
        if item:
            result.append(monpa.cut(item))

    tmp_result =""
    for k in range(len(result)):
        tmp_result += " ".join(result[k])
    fastt_free.loc[i,'cut_text'] = tmp_result
    print('i=:',i)
    #break

fastt_free.head(), len(fastt_free)

# %%
fastt_free = get_cleaned_seg(fastt_free)
fastt_free.head(), len(fastt_free)

# %%
fastt_free = fastt_free.rename_axis('index').reset_index()
fastt_free.head()

# %%
fastt_free = fastt_free[['index', 'TITLE', 'cleaned_text', 'FROM', 'TIME']]
fastt_free.columns = ['CATEGORY', 'TITLE', 'cleaned_text', 'FROM', 'TIME']

fastt_free.head()

# %%
fastt_free.to_csv("/Users/lilywang/Library/CloudStorage/OneDrive-臺北醫學大學/畢業專題/資料與程式碼/Reader Emotion(情感分析資料)/中時＋自由/快篩試劑/自由/快篩試劑_cleaned.csv", header=True, index=False, encoding="utf-8")

# %% [markdown]
# ## 居家快篩-中時

# %%
homefast_china = pd.read_csv("/Users/lilywang/Library/CloudStorage/OneDrive-臺北醫學大學/畢業專題/資料與程式碼/Reader Emotion(情感分析資料)/中時＋自由/居家快篩/中時/居家快篩.csv", encoding = 'utf-8')
homefast_china.head()

# %%
from monpa import utils

homefast_china.fillna('',inplace=True)

for i in range(len(homefast_china)):
    result = []
    for item in utils.short_sentence(homefast_china.loc[i,'TITLE'] + homefast_china.loc[i,'CONTENT']):
        if item:
            result.append(monpa.cut(item))

    tmp_result =""
    for k in range(len(result)):
        tmp_result += " ".join(result[k])
    homefast_china.loc[i,'cut_text'] = tmp_result
    print('i=:',i)
    #break

homefast_china.head(), len(homefast_china)

# %%
homefast_china = get_cleaned_seg(homefast_china)
homefast_china.head(), len(homefast_china)

# %%
homefast_china = homefast_china.rename_axis('index').reset_index()
homefast_china

# %%
homefast_china = homefast_china[['index', 'TITLE', 'cleaned_text', 'FROM', 'TIME']]
homefast_china.columns = ['CATEGORY', 'TITLE', 'cleaned_text', 'FROM', 'TIME']
homefast_china

# %%
homefast_china.to_csv("/Users/lilywang/Library/CloudStorage/OneDrive-臺北醫學大學/畢業專題/資料與程式碼/Reader Emotion(情感分析資料)/中時＋自由/居家快篩/中時/居家快篩_cleaned.csv", header=True, index=False, encoding="utf-8")

# %% [markdown]
# ## 居家快篩-自由

# %%
homefast_free = pd.read_csv("/Users/lilywang/Library/CloudStorage/OneDrive-臺北醫學大學/畢業專題/資料與程式碼/Reader Emotion(情感分析資料)/中時＋自由/居家快篩/自由/居家快篩.csv", encoding = 'utf-8')
homefast_free.head()

# %%
from monpa import utils

homefast_free.fillna('',inplace=True)

for i in range(len(homefast_free)):
    result = []
    for item in utils.short_sentence(homefast_free.loc[i,'TITLE'] + homefast_free.loc[i,'CONTENT']):
        if item:
            result.append(monpa.cut(item))

    tmp_result =""
    for k in range(len(result)):
        tmp_result += " ".join(result[k])
    homefast_free.loc[i,'cut_text'] = tmp_result
    print('i=:',i)
    #break

homefast_free.head(), len(homefast_free)

# %%
homefast_free = get_cleaned_seg(homefast_free)
homefast_free.head(), len(homefast_free)

# %%
homefast_free = homefast_free.rename_axis('index').reset_index()
homefast_free

# %%
homefast_free = homefast_free[['index', 'TITLE', 'cleaned_text', 'FROM', 'TIME']]
homefast_free.columns = ['CATEGORY', 'TITLE', 'cleaned_text', 'FROM', 'TIME']
homefast_free

# %%
homefast_free.to_csv("/Users/lilywang/Library/CloudStorage/OneDrive-臺北醫學大學/畢業專題/資料與程式碼/Reader Emotion(情感分析資料)/中時＋自由/居家快篩/自由/居家快篩_cleaned.csv", header=True, index=False, encoding="utf-8")

# %% [markdown]
# ## 居家照顧-中時

# %%
homecare_china = pd.read_csv("/Users/lilywang/Library/CloudStorage/OneDrive-臺北醫學大學/畢業專題/資料與程式碼/Reader Emotion(情感分析資料)/中時＋自由/居家照顧/中時/居家照顧.csv", encoding = 'utf-8')
homecare_china.head()

# %%
from monpa import utils

homecare_china.fillna('',inplace=True)

for i in range(len(homecare_china)):
    result = []
    for item in utils.short_sentence(homecare_china.loc[i,'TITLE'] + homecare_china.loc[i,'CONTENT']):
        if item:
            result.append(monpa.cut(item))

    tmp_result =""
    for k in range(len(result)):
        tmp_result += " ".join(result[k])
    homecare_china.loc[i,'cut_text'] = tmp_result
    print('i=:',i)
    #break

homecare_china.head(), len(homecare_china)

# %%
homecare_china = get_cleaned_seg(homecare_china)
homecare_china.head(), len(homecare_china)

# %%
homecare_china = homecare_china.rename_axis('index').reset_index()
homecare_china.head()

# %%
homecare_china = homecare_china[['index', 'TITLE', 'cleaned_text', 'FROM', 'TIME']]
homecare_china.columns = ['CATEGORY', 'TITLE', 'cleaned_text', 'FROM', 'TIME']
homecare_china.head()

# %%
homecare_china.to_csv("/Users/lilywang/Library/CloudStorage/OneDrive-臺北醫學大學/畢業專題/資料與程式碼/Reader Emotion(情感分析資料)/中時＋自由/居家照顧/中時/居家照顧_cleaned.csv", header=True, index=False, encoding="utf-8")

# %% [markdown]
# ## 居家照顧-自由

# %%
homecare_free = pd.read_csv("/Users/lilywang/Library/CloudStorage/OneDrive-臺北醫學大學/畢業專題/資料與程式碼/Reader Emotion(情感分析資料)/中時＋自由/居家照顧/自由/居家照顧.csv", encoding = 'utf-8')
homecare_free.head()

# %%
from monpa import utils

selft_china.fillna('',inplace=True)

for i in range(len(homecare_free)):
    result = []
    for item in utils.short_sentence(homecare_free.loc[i,'TITLE'] + homecare_free.loc[i,'CONTENT']):
        if item:
            result.append(monpa.cut(item))

    tmp_result =""
    for k in range(len(result)):
        tmp_result += " ".join(result[k])
    homecare_free.loc[i,'cut_text'] = tmp_result
    print('i=:',i)
    #break

homecare_free.head(), len(homecare_free)

# %%
homecare_free = get_cleaned_seg(homecare_free)
homecare_free.head(), len(homecare_free)

# %%
homecare_free = homecare_free.rename_axis('index').reset_index()
homecare_free

# %%
homecare_free = homecare_free[['index', 'TITLE', 'cleaned_text', 'FROM', 'TIME']]
homecare_free.columns = ['CATEGORY', 'TITLE', 'cleaned_text', 'FROM', 'TIME']
homecare_free

# %%
homecare_free.to_csv("/Users/lilywang/Library/CloudStorage/OneDrive-臺北醫學大學/畢業專題/資料與程式碼/Reader Emotion(情感分析資料)/中時＋自由/居家照顧/自由/居家照顧_cleaned.csv", header=True, index=False, encoding="utf-8")

# %% [markdown]
# ## 居家隔離-中時

# %%
homeisolation_china = pd.read_csv("/Users/lilywang/Library/CloudStorage/OneDrive-臺北醫學大學/畢業專題/資料與程式碼/Reader Emotion(情感分析資料)/中時＋自由/居家隔離 居隔/中時/居家隔離.csv", encoding = 'utf-8')
homeisolation_china.head()

# %% [markdown]
# ## 居隔-中時

# %%
homeiso_china = pd.read_csv("/Users/lilywang/Library/CloudStorage/OneDrive-臺北醫學大學/畢業專題/資料與程式碼/Reader Emotion(情感分析資料)/中時＋自由/居家隔離 居隔/中時/居隔.csv", encoding = 'utf-8')
homeiso_china.head()

# %% [markdown]
# ### 合併表格

# %%
homeiso_china_new = pd.concat([homeisolation_china, homeiso_china], axis = 0)
homeiso_china_new.head()

# %%
homeiso_china_new = homeiso_china_new.rename_axis('index').reset_index()
homeiso_china_new

# %% [markdown]
# ## 刪除舊的合併欄位index

# %%
homeiso_china_new = homeiso_china_new.drop("index", axis = 1)
homeiso_china_new.head()

# %%
from monpa import utils

homeiso_china_new.fillna('',inplace=True)

for i in range(len(homeiso_china_new)):
    result = []
    for item in utils.short_sentence(homeiso_china_new.loc[i,'TITLE'] + homeiso_china_new.loc[i,'CONTENT']):
        if item:
            result.append(monpa.cut(item))

    tmp_result =""
    for k in range(len(result)):
        tmp_result += " ".join(result[k])
    homeiso_china_new.loc[i,'cut_text'] = tmp_result
    print('i=:',i)
    #break

homeiso_china_new.head(), len(homeiso_china_new)

# %%
homeiso_china_new = get_cleaned_seg(homeiso_china_new)
homeiso_china_new.head(), len(homeiso_china_new)

# %%
homeiso_china_new = homeiso_china_new.rename_axis('index').reset_index()
homeiso_china_new.head()

# %%
homeiso_china_new = homeiso_china_new[['index', 'TITLE', 'cleaned_text', 'FROM', 'TIME']]
homeiso_china_new.columns = ['CATEGORY', 'TITLE', 'cleaned_text', 'FROM', 'TIME']
homeiso_china_new.head()

# %%
homeiso_china_new.to_csv("/Users/lilywang/Library/CloudStorage/OneDrive-臺北醫學大學/畢業專題/資料與程式碼/Reader Emotion(情感分析資料)/中時＋自由/居家隔離 居隔/中時/居家隔離_cleaned.csv", header=True, index=False, encoding="utf-8")

# %% [markdown]
# ## 居家隔離-自由

# %%
homeisolation_free = pd.read_csv("/Users/lilywang/Library/CloudStorage/OneDrive-臺北醫學大學/畢業專題/資料與程式碼/Reader Emotion(情感分析資料)/中時＋自由/居家隔離 居隔/自由/居家隔離.csv", encoding = 'utf-8')
homeisolation_free.head()
# Out:
#                             TITLE                 TIME CATEGORY  \
# 0       竹市疫調小組請刑警協助「查案」 讓隱匿足跡一覽無遺  2021-05-30 13:44:59     life
# 1                新北增7例 北市房屋代銷鏈再擴大  2022-02-19 05:30:00     life
# 2            東縣卑南群聚案新增2確診 3天累計10例  2022-03-29 13:21:54     life
# 3  司法院：「非雙北」法院若案件當事人或律師住雙北 也應暫緩開庭  2021-05-17 17:20:16  society
# 4                壓不下北農群聚 柯文哲求助王必勝  2021-06-27 05:30:00     life
#
#                                          DESCRIPTION  \
# 0  新竹市目前累積確診個案14人，而透過疫調掌握確診者接觸者與足跡，成防守竹市疫情關鍵，而竹市疫...
# 1  全與在餐廳、KTV聚會相關 足跡遍布台北捷運、板橋、永和等超商新北市昨天新增七例武漢肺炎（新...
# 2  台東卑南群聚案今再新增2名確診案例，1名60多歲男性，CT值17.7，還有昨確診尚無案號70...
# 3  台北市、雙北市本月15日提升至三級警戒至本月28日，司法院也宣布這段期間雙北市相關法院以暫緩...
# 4  擴大PCR 柯：一萬劑AZ一週打完台北農產運銷公司、環南市場和新北市家禽屠宰場群聚感染確診人...
#
#                                              CONTENT  FROM  \
# 0  新竹市疫調小組因有刑警及社會民政和教育單位的成員加入，讓隱藏足跡一覽無遺，並得以掌握疫情發展...  自由時報
# 1  三重區某幼兒園的男童確診，衛生局匡列師生四百多人普篩，大量人潮擠滿醫院篩檢，民眾抱怨亂成一團...  自由時報
# 2  台東卑南群聚案今再新增2名，3日累計10人，縣府籲民眾盡速快篩，防堵疫情擴散。（記者陳賢義攝...  自由時報
# ...

# %% [markdown]
# ## 居隔-自由

# %%
homeiso_free = pd.read_csv("/Users/lilywang/Library/CloudStorage/OneDrive-臺北醫學大學/畢業專題/資料與程式碼/Reader Emotion(情感分析資料)/中時＋自由/居家隔離 居隔/自由/居隔.csv", encoding = 'utf-8')
homeiso_free.head()
# Out:
#                       TITLE                 TIME CATEGORY  \
# 0            屏東確診者+5 縣府公告足跡  2022-04-08 05:30:00     life
# 1   屏東確診+14 娛樂場所小吃部相關群聚再增7例  2022-04-13 16:58:24     life
# 2  高中以下學生疑似或確診 教部要求即時回報國教署長  2022-02-17 15:41:49     life
# 3            01/27 各報重點新聞一覽  2022-01-28 08:02:10     life
# 4      桃園新街國小+3 2496師生家長採檢陰  2022-03-02 05:30:00     life
#
#                                          DESCRIPTION  \
# 0  屏東縣昨新增五名確診者，外縣市案足跡則有六例，縣府公告足跡，共匡列八十五人，呼籲有重疊者儘速...
# 1  屏東縣政府今天（13日）新增14例本土武漢肺炎（新型冠狀病毒病，COVID-19）確診個案，...
# 2  武漢肺炎（新型冠狀病毒病，COVID-19）國內疫情升高，教育部今發布「教育部主管高級中等以...
# 3                                  自由時報全國居隔逾8千人 今年新高
# 4  武肺本土疫情持續維持個位數確診！昨天新增四例，桃園市米迪幼兒園群聚感染衍伸相關案例就有三例（...
#
#                                              CONTENT  FROM  \
# 0  〔記者陳彥廷／屏東報導〕屏東縣昨新增五名確診者，外縣市案足跡則有六例，縣府公告足跡，共匡列八...  自由時報
# 1  13日屏縣新增14例確診。（圖由屏縣府提供）\n〔記者羅欣貞／屏東報導〕屏東縣政府今天（13...  自由時報
# 2  教育部主管高中以下學生疑似或確診，教育部要求學校須即時回報國教署長。（記者林曉雲攝）\n〔記...  自由時報
# ...

# %%
homeiso_free_new = pd.concat([homeisolation_free, homeiso_free], axis = 0)
homeiso_free_new.head()
# Out:
#                             TITLE                 TIME CATEGORY  \
# 0       竹市疫調小組請刑警協助「查案」 讓隱匿足跡一覽無遺  2021-05-30 13:44:59     life
# 1                新北增7例 北市房屋代銷鏈再擴大  2022-02-19 05:30:00     life
# 2            東縣卑南群聚案新增2確診 3天累計10例  2022-03-29 13:21:54     life
# 3  司法院：「非雙北」法院若案件當事人或律師住雙北 也應暫緩開庭  2021-05-17 17:20:16  society
# 4                壓不下北農群聚 柯文哲求助王必勝  2021-06-27 05:30:00     life
#
#                                          DESCRIPTION  \
# 0  新竹市目前累積確診個案14人，而透過疫調掌握確診者接觸者與足跡，成防守竹市疫情關鍵，而竹市疫...
# 1  全與在餐廳、KTV聚會相關 足跡遍布台北捷運、板橋、永和等超商新北市昨天新增七例武漢肺炎（新...
# 2  台東卑南群聚案今再新增2名確診案例，1名60多歲男性，CT值17.7，還有昨確診尚無案號70...
# 3  台北市、雙北市本月15日提升至三級警戒至本月28日，司法院也宣布這段期間雙北市相關法院以暫緩...
# 4  擴大PCR 柯：一萬劑AZ一週打完台北農產運銷公司、環南市場和新北市家禽屠宰場群聚感染確診人...
#
#                                              CONTENT  FROM  \
# 0  新竹市疫調小組因有刑警及社會民政和教育單位的成員加入，讓隱藏足跡一覽無遺，並得以掌握疫情發展...  自由時報
# 1  三重區某幼兒園的男童確診，衛生局匡列師生四百多人普篩，大量人潮擠滿醫院篩檢，民眾抱怨亂成一團...  自由時報
# 2  台東卑南群聚案今再新增2名，3日累計10人，縣府籲民眾盡速快篩，防堵疫情擴散。（記者陳賢義攝...  自由時報
# ...

# %%
homeiso_free_new = homeiso_free_new.rename_axis('index').reset_index()
homeiso_free_new.head()
# Out:
#    index                           TITLE                 TIME CATEGORY  \
# 0      0       竹市疫調小組請刑警協助「查案」 讓隱匿足跡一覽無遺  2021-05-30 13:44:59     life
# 1      1                新北增7例 北市房屋代銷鏈再擴大  2022-02-19 05:30:00     life
# 2      2            東縣卑南群聚案新增2確診 3天累計10例  2022-03-29 13:21:54     life
# 3      3  司法院：「非雙北」法院若案件當事人或律師住雙北 也應暫緩開庭  2021-05-17 17:20:16  society
# 4      4                壓不下北農群聚 柯文哲求助王必勝  2021-06-27 05:30:00     life
#
#                                          DESCRIPTION  \
# 0  新竹市目前累積確診個案14人，而透過疫調掌握確診者接觸者與足跡，成防守竹市疫情關鍵，而竹市疫...
# 1  全與在餐廳、KTV聚會相關 足跡遍布台北捷運、板橋、永和等超商新北市昨天新增七例武漢肺炎（新...
# 2  台東卑南群聚案今再新增2名確診案例，1名60多歲男性，CT值17.7，還有昨確診尚無案號70...
# 3  台北市、雙北市本月15日提升至三級警戒至本月28日，司法院也宣布這段期間雙北市相關法院以暫緩...
# 4  擴大PCR 柯：一萬劑AZ一週打完台北農產運銷公司、環南市場和新北市家禽屠宰場群聚感染確診人...
#
#                                              CONTENT  FROM  \
# 0  新竹市疫調小組因有刑警及社會民政和教育單位的成員加入，讓隱藏足跡一覽無遺，並得以掌握疫情發展...  自由時報
# 1  三重區某幼兒園的男童確診，衛生局匡列師生四百多人普篩，大量人潮擠滿醫院篩檢，民眾抱怨亂成一團...  自由時報
# ...

# %%
homeiso_free_new = homeiso_free_new.drop("index", axis = 1)
homeiso_free_new.head()
# Out:
#                             TITLE                 TIME CATEGORY  \
# 0       竹市疫調小組請刑警協助「查案」 讓隱匿足跡一覽無遺  2021-05-30 13:44:59     life
# 1                新北增7例 北市房屋代銷鏈再擴大  2022-02-19 05:30:00     life
# 2            東縣卑南群聚案新增2確診 3天累計10例  2022-03-29 13:21:54     life
# 3  司法院：「非雙北」法院若案件當事人或律師住雙北 也應暫緩開庭  2021-05-17 17:20:16  society
# 4                壓不下北農群聚 柯文哲求助王必勝  2021-06-27 05:30:00     life
#
#                                          DESCRIPTION  \
# 0  新竹市目前累積確診個案14人，而透過疫調掌握確診者接觸者與足跡，成防守竹市疫情關鍵，而竹市疫...
# 1  全與在餐廳、KTV聚會相關 足跡遍布台北捷運、板橋、永和等超商新北市昨天新增七例武漢肺炎（新...
# 2  台東卑南群聚案今再新增2名確診案例，1名60多歲男性，CT值17.7，還有昨確診尚無案號70...
# 3  台北市、雙北市本月15日提升至三級警戒至本月28日，司法院也宣布這段期間雙北市相關法院以暫緩...
# 4  擴大PCR 柯：一萬劑AZ一週打完台北農產運銷公司、環南市場和新北市家禽屠宰場群聚感染確診人...
#
#                                              CONTENT  FROM  \
# 0  新竹市疫調小組因有刑警及社會民政和教育單位的成員加入，讓隱藏足跡一覽無遺，並得以掌握疫情發展...  自由時報
# 1  三重區某幼兒園的男童確診，衛生局匡列師生四百多人普篩，大量人潮擠滿醫院篩檢，民眾抱怨亂成一團...  自由時報
# 2  台東卑南群聚案今再新增2名，3日累計10人，縣府籲民眾盡速快篩，防堵疫情擴散。（記者陳賢義攝...  自由時報
# ...

# %%
from monpa import utils

homeiso_free_new.fillna('',inplace=True)

for i in range(len(homeiso_free_new)):
    result = []
    for item in utils.short_sentence(homeiso_free_new.loc[i,'TITLE'] + homeiso_free_new.loc[i,'CONTENT']):
        if item:
            result.append(monpa.cut(item))

    tmp_result =""
    for k in range(len(result)):
        tmp_result += " ".join(result[k])
    homeiso_free_new.loc[i,'cut_text'] = tmp_result
    print('i=:',i)
    #break

homeiso_free_new.head(), len(homeiso_free_new)
# Out:
# /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/monpa/crf_layer.py:374: UserWarning: where received a uint8 condition tensor. This behavior is deprecated and will be removed in a future version of PyTorch. Use a boolean condition instead. (Triggered internally at  ../aten/src/ATen/native/TensorCompare.cpp:328.)
#   score = torch.where(mask[i].unsqueeze(1), next_score, score)
# i=: 0
# i=: 1
# i=: 2
# i=: 3
# i=: 4
# i=: 5
# i=: 6
# i=: 7
# i=: 8
# i=: 9
# i=: 10
# i=: 11
# i=: 12
# i=: 13
# i=: 14
# i=: 15
# i=: 16
# i=: 17
# i=: 18
# i=: 19
# i=: 20
# i=: 21
# i=: 22
# i=: 23
# i=: 24
# i=: 25
# i=: 26
# i=: 27
# i=: 28
# i=: 29
# i=: 30
# i=: 31
# i=: 32
# i=: 33
# i=: 34
# i=: 35
# i=: 36
# i=: 37
# i=: 38
# i=: 39
# i=: 40
# i=: 41
# i=: 42
# i=: 43
# i=: 44
# i=: 45
# i=: 46
# i=: 47
# i=: 48
# i=: 49
# i=: 50
# i=: 51
# i=: 52
# i=: 53
# i=: 54
# i=: 55
# i=: 56
# i=: 57
# i=: 58
# i=: 59
# i=: 60
# i=: 61
# i=: 62
# i=: 63
# i=: 64
# i=: 65
# ...

# %%
homeiso_free_new = get_cleaned_seg(homeiso_free_new)
homeiso_free_new.head(), len(homeiso_free_new)
# Out:
# (                            TITLE                 TIME CATEGORY  \
#  0       竹市疫調小組請刑警協助「查案」 讓隱匿足跡一覽無遺  2021-05-30 13:44:59     life
#  1                新北增7例 北市房屋代銷鏈再擴大  2022-02-19 05:30:00     life
#  2            東縣卑南群聚案新增2確診 3天累計10例  2022-03-29 13:21:54     life
#  3  司法院：「非雙北」法院若案件當事人或律師住雙北 也應暫緩開庭  2021-05-17 17:20:16  society
#  4                壓不下北農群聚 柯文哲求助王必勝  2021-06-27 05:30:00     life
#
#                                           DESCRIPTION  \
#  0  新竹市目前累積確診個案14人，而透過疫調掌握確診者接觸者與足跡，成防守竹市疫情關鍵，而竹市疫...
#  1  全與在餐廳、KTV聚會相關 足跡遍布台北捷運、板橋、永和等超商新北市昨天新增七例武漢肺炎（新...
#  2  台東卑南群聚案今再新增2名確診案例，1名60多歲男性，CT值17.7，還有昨確診尚無案號70...
#  3  台北市、雙北市本月15日提升至三級警戒至本月28日，司法院也宣布這段期間雙北市相關法院以暫緩...
#  4  擴大PCR 柯：一萬劑AZ一週打完台北農產運銷公司、環南市場和新北市家禽屠宰場群聚感染確診人...
#
#                                               CONTENT  FROM  \
#  0  新竹市疫調小組因有刑警及社會民政和教育單位的成員加入，讓隱藏足跡一覽無遺，並得以掌握疫情發展...  自由時報
#  1  三重區某幼兒園的男童確診，衛生局匡列師生四百多人普篩，大量人潮擠滿醫院篩檢，民眾抱怨亂成一團...  自由時報
#  2  台東卑南群聚案今再新增2名，3日累計10人，縣府籲民眾盡速快篩，防堵疫情擴散。（記者陳賢義攝...  自由時報
# ...

# %%
homeiso_free_new = homeiso_free_new.rename_axis('index').reset_index()
homeiso_free_new
# Out:
#      index                           TITLE                 TIME CATEGORY  \
# 0        0       竹市疫調小組請刑警協助「查案」 讓隱匿足跡一覽無遺  2021-05-30 13:44:59     life
# 1        1                新北增7例 北市房屋代銷鏈再擴大  2022-02-19 05:30:00     life
# 2        2            東縣卑南群聚案新增2確診 3天累計10例  2022-03-29 13:21:54     life
# 3        3  司法院：「非雙北」法院若案件當事人或律師住雙北 也應暫緩開庭  2021-05-17 17:20:16  society
# 4        4                壓不下北農群聚 柯文哲求助王必勝  2021-06-27 05:30:00     life
# ..     ...                             ...                  ...      ...
# 632    632  桃園新興高中學生確診 51人居隔、4928位師生採檢全數陰性  2022-02-25 09:15:07     life
# 633    633        竹市今天新增3病例  累計30例、無重症、0死亡  2021-06-11 15:52:24     life
# 634    634             電子圍籬告警異常  新北日高達459件  2022-04-13 12:48:56     life
# 635    635                雲林＋4 10診所供免費快篩試劑  2022-04-12 05:30:00     life
# 636    636              台東成功進香團增7例 3人居隔陰轉陽  2022-04-18 14:02:08     life
#
#                                            DESCRIPTION  \
# ...

# %%
homeiso_free_new = homeiso_free_new[['index', 'TITLE', 'cleaned_text', 'FROM', 'TIME']]
homeiso_free_new.columns = ['CATEGORY', 'TITLE', 'cleaned_text', 'FROM', 'TIME']
homeiso_free_new
# Out:
#      CATEGORY                           TITLE  \
# 0           0       竹市疫調小組請刑警協助「查案」 讓隱匿足跡一覽無遺
# 1           1                新北增7例 北市房屋代銷鏈再擴大
# 2           2            東縣卑南群聚案新增2確診 3天累計10例
# 3           3  司法院：「非雙北」法院若案件當事人或律師住雙北 也應暫緩開庭
# 4           4                壓不下北農群聚 柯文哲求助王必勝
# ..        ...                             ...
# 632       632  桃園新興高中學生確診 51人居隔、4928位師生採檢全數陰性
# 633       633        竹市今天新增3病例  累計30例、無重症、0死亡
# 634       634             電子圍籬告警異常  新北日高達459件
# 635       635                雲林＋4 10診所供免費快篩試劑
# 636       636              台東成功進香團增7例 3人居隔陰轉陽
#
#                                           cleaned_text  FROM  \
# 0    竹市 疫調小組 請 刑警 協助 查案 隱匿 足跡 竹市 疫調 刑警 社會 民政 教育 單位 ...  自由時報
# 1    新北 增 例 北市 房屋 代銷 鏈 擴大 幼兒園 男童 確診 衛生局 匡列 師生 四百多 普...  自由時報
# 2    東縣 卑南 群聚案 新增 確診 天 累計 例 台東 卑南 群聚案 新增 名 日 累計 縣府 ...  自由時報
# 3    司法院 非 雙北 法院 案件 律師 住 雙北 應 暫緩 開庭 司法院 表示 非 雙北 法院 ...  自由時報
# 4    壓 北農 群聚 柯文哲 求助 王必勝 台北市 果菜 市場 蔬菜 零批場 實施 體溫 監控 消...  自由時報
# ...

# %%
homeiso_free_new.to_csv("/Users/lilywang/Library/CloudStorage/OneDrive-臺北醫學大學/畢業專題/資料與程式碼/Reader Emotion(情感分析資料)/中時＋自由/居家隔離 居隔/自由/居家隔離_cleaned.csv", header=True, index=False, encoding="utf-8")

# %% [markdown]
# ## 居家檢疫 居檢-中時

# %%
homequarantine_china = pd.read_csv("/Users/lilywang/Library/CloudStorage/OneDrive-臺北醫學大學/畢業專題/資料與程式碼/Reader Emotion(情感分析資料)/中時＋自由/居家檢疫 居檢/中時/居家檢疫.csv", encoding = 'utf-8')
homequarantine_china.head()
# Out:
#                         TITLE                 TIME CATEGORY  \
# 0           高端60萬劑到位 第六輪23日開打  2021-08-12 04:10:00     財經要聞
# 1                 春節檢疫派員至旅館採檢  2021-12-17 04:10:00     地方新聞
# 2       今增3本土！雙北有兩人 1台籍60歲男死亡  2022-02-25 13:51:00       生活
# 3   入境居檢鬆綁首日 指揮中心：落地採檢陽性率較上周低  2022-03-08 14:59:58       生活
# 4  境外移工確診攀增 侯友宜：國外篩檢報告可不可信待討論  2020-12-07 11:55:47       生活
#
#                                          DESCRIPTION  \
# 0  衛長陳時中11日宣布，第六輪疫苗施打將提供高端接種，23日起開打，疫苗數量至少有60多萬劑，...
# 1  春節檢疫專案14日起跑，因應返鄉者眾，負責居家檢疫的桃園市民政局提出安排採檢、安排移動交通工...
# 2  國內今天新增3例本土個案，皆為新案，包括一名美國境外移入個案的家人，以及一對雙北父子檔確診，...
# 3  隨著新冠肺炎疫情趨緩，昨起入境檢疫天數由14天減至10天。根據中央流行疫情指揮中心統計，昨落...
# 4  境外移工確診個案攀增，新北市長侯友宜今談及歡樂耶誕城防疫措施表示，政府雖規定境外移入者須檢附...
#
#                                              CONTENT             KEYWORDS  \
# 0  衛長陳時中11日宣布，第六輪疫苗施打將提供高端接種，23日起開打，疫苗數量至少有60多萬劑，...      大陸,高端,陳時中,疫苗,檢疫
# 1  春節檢疫專案14日起跑，因應返鄉者眾，負責居家檢疫的桃園市民政局提出安排採檢、安排移動交通工...     採檢,方案,計程車,二階段,檢疫
# ...

# %%
homequa_china = pd.read_csv("/Users/lilywang/Library/CloudStorage/OneDrive-臺北醫學大學/畢業專題/資料與程式碼/Reader Emotion(情感分析資料)/中時＋自由/居家檢疫 居檢/中時/居檢.csv", encoding = 'utf-8')
homequa_china.head()
# Out:
#                         TITLE                 TIME CATEGORY  \
# 0                 春節檢疫派員至旅館採檢  2021-12-17 04:10:00     地方新聞
# 1   入境居檢鬆綁首日 指揮中心：落地採檢陽性率較上周低  2022-03-08 14:59:58       生活
# 2    通過抗體檢驗縮短居檢 指揮中心：大陸疫苗一體適用  2021-03-27 15:22:34       生活
# 3        民眾居檢期間外出 中市府：最高將罰20萬  2022-03-01 11:18:46       生活
# 4  機組員發起「黃飄帶行動」高喊：居檢不派飛、我要喘息日  2021-10-28 15:19:56       生活
#
#                                          DESCRIPTION  \
# 0  春節檢疫專案14日起跑，因應返鄉者眾，負責居家檢疫的桃園市民政局提出安排採檢、安排移動交通工...
# 1  隨著新冠肺炎疫情趨緩，昨起入境檢疫天數由14天減至10天。根據中央流行疫情指揮中心統計，昨落...
# 2  中央流行疫情指揮中心指揮官陳時中昨預告推動2階段邊境鬆綁措施，其中第1階段是針對接種過疫苗者...
# 3  台中市一名民眾在居家檢疫期間，誤以為居隔時間已結束違法外出，民政局1日表示，經調查該名民眾誤...
# 4  國籍航空61歲委內瑞拉籍機師23日在桃園市住處猝死，桃園市機師職業工會28日在3處檢疫旅館發...
#
#                                              CONTENT             KEYWORDS  \
# 0  春節檢疫專案14日起跑，因應返鄉者眾，負責居家檢疫的桃園市民政局提出安排採檢、安排移動交通工...     採檢,方案,計程車,二階段,檢疫
# 1  隨著新冠肺炎疫情趨緩，昨起入境檢疫天數由14天減至10天。根據中央流行疫情指揮中心統計，昨落...     陽性率,落地採檢,新冠肺炎,台灣
# ...

# %%
homequa_china_new = pd.concat([homequarantine_china, homequa_china], axis = 0)
homequa_china_new
# Out:
#                         TITLE                 TIME CATEGORY  \
# 0           高端60萬劑到位 第六輪23日開打  2021-08-12 04:10:00     財經要聞
# 1                 春節檢疫派員至旅館採檢  2021-12-17 04:10:00     地方新聞
# 2       今增3本土！雙北有兩人 1台籍60歲男死亡  2022-02-25 13:51:00       生活
# 3   入境居檢鬆綁首日 指揮中心：落地採檢陽性率較上周低  2022-03-08 14:59:58       生活
# 4  境外移工確診攀增 侯友宜：國外篩檢報告可不可信待討論  2020-12-07 11:55:47       生活
#
#                                          DESCRIPTION  \
# 0  衛長陳時中11日宣布，第六輪疫苗施打將提供高端接種，23日起開打，疫苗數量至少有60多萬劑，...
# 1  春節檢疫專案14日起跑，因應返鄉者眾，負責居家檢疫的桃園市民政局提出安排採檢、安排移動交通工...
# 2  國內今天新增3例本土個案，皆為新案，包括一名美國境外移入個案的家人，以及一對雙北父子檔確診，...
# 3  隨著新冠肺炎疫情趨緩，昨起入境檢疫天數由14天減至10天。根據中央流行疫情指揮中心統計，昨落...
# 4  境外移工確診個案攀增，新北市長侯友宜今談及歡樂耶誕城防疫措施表示，政府雖規定境外移入者須檢附...
#
#                                              CONTENT             KEYWORDS  \
# 0  衛長陳時中11日宣布，第六輪疫苗施打將提供高端接種，23日起開打，疫苗數量至少有60多萬劑，...      大陸,高端,陳時中,疫苗,檢疫
# 1  春節檢疫專案14日起跑，因應返鄉者眾，負責居家檢疫的桃園市民政局提出安排採檢、安排移動交通工...     採檢,方案,計程車,二階段,檢疫
# ...

# %%
homequa_china_new = homequa_china_new.rename_axis('index').reset_index()
homequa_china_new.head()
# Out:
#    index                       TITLE                 TIME CATEGORY  \
# 0      0           高端60萬劑到位 第六輪23日開打  2021-08-12 04:10:00     財經要聞
# 1      1                 春節檢疫派員至旅館採檢  2021-12-17 04:10:00     地方新聞
# 2      2       今增3本土！雙北有兩人 1台籍60歲男死亡  2022-02-25 13:51:00       生活
# 3      3   入境居檢鬆綁首日 指揮中心：落地採檢陽性率較上周低  2022-03-08 14:59:58       生活
# 4      4  境外移工確診攀增 侯友宜：國外篩檢報告可不可信待討論  2020-12-07 11:55:47       生活
#
#                                          DESCRIPTION  \
# 0  衛長陳時中11日宣布，第六輪疫苗施打將提供高端接種，23日起開打，疫苗數量至少有60多萬劑，...
# 1  春節檢疫專案14日起跑，因應返鄉者眾，負責居家檢疫的桃園市民政局提出安排採檢、安排移動交通工...
# 2  國內今天新增3例本土個案，皆為新案，包括一名美國境外移入個案的家人，以及一對雙北父子檔確診，...
# 3  隨著新冠肺炎疫情趨緩，昨起入境檢疫天數由14天減至10天。根據中央流行疫情指揮中心統計，昨落...
# 4  境外移工確診個案攀增，新北市長侯友宜今談及歡樂耶誕城防疫措施表示，政府雖規定境外移入者須檢附...
#
#                                              CONTENT             KEYWORDS  \
# 0  衛長陳時中11日宣布，第六輪疫苗施打將提供高端接種，23日起開打，疫苗數量至少有60多萬劑，...      大陸,高端,陳時中,疫苗,檢疫
# 1  春節檢疫專案14日起跑，因應返鄉者眾，負責居家檢疫的桃園市民政局提出安排採檢、安排移動交通工...     採檢,方案,計程車,二階段,檢疫
# ...

# %%
homequa_china_new= homequa_china_new.drop("index", axis = 1)
homequa_china_new.head()
# Out:
#                         TITLE                 TIME CATEGORY  \
# 0           高端60萬劑到位 第六輪23日開打  2021-08-12 04:10:00     財經要聞
# 1                 春節檢疫派員至旅館採檢  2021-12-17 04:10:00     地方新聞
# 2       今增3本土！雙北有兩人 1台籍60歲男死亡  2022-02-25 13:51:00       生活
# 3   入境居檢鬆綁首日 指揮中心：落地採檢陽性率較上周低  2022-03-08 14:59:58       生活
# 4  境外移工確診攀增 侯友宜：國外篩檢報告可不可信待討論  2020-12-07 11:55:47       生活
#
#                                          DESCRIPTION  \
# 0  衛長陳時中11日宣布，第六輪疫苗施打將提供高端接種，23日起開打，疫苗數量至少有60多萬劑，...
# 1  春節檢疫專案14日起跑，因應返鄉者眾，負責居家檢疫的桃園市民政局提出安排採檢、安排移動交通工...
# 2  國內今天新增3例本土個案，皆為新案，包括一名美國境外移入個案的家人，以及一對雙北父子檔確診，...
# 3  隨著新冠肺炎疫情趨緩，昨起入境檢疫天數由14天減至10天。根據中央流行疫情指揮中心統計，昨落...
# 4  境外移工確診個案攀增，新北市長侯友宜今談及歡樂耶誕城防疫措施表示，政府雖規定境外移入者須檢附...
#
#                                              CONTENT             KEYWORDS  \
# 0  衛長陳時中11日宣布，第六輪疫苗施打將提供高端接種，23日起開打，疫苗數量至少有60多萬劑，...      大陸,高端,陳時中,疫苗,檢疫
# 1  春節檢疫專案14日起跑，因應返鄉者眾，負責居家檢疫的桃園市民政局提出安排採檢、安排移動交通工...     採檢,方案,計程車,二階段,檢疫
# ...

# %%
from monpa import utils

homequa_china_new.fillna('',inplace=True)

for i in range(len(homequa_china_new)):
    result = []
    for item in utils.short_sentence(homequa_china_new.loc[i,'TITLE'] + homequa_china_new.loc[i,'CONTENT']):
        if item:
            result.append(monpa.cut(item))

    tmp_result =""
    for k in range(len(result)):
        tmp_result += " ".join(result[k])
    homequa_china_new.loc[i,'cut_text'] = tmp_result
    print('i=:',i)
    #break

homequa_china_new.head(), len(homequa_china_new)
# Out:
# i=: 0
# i=: 1
# i=: 2
# i=: 3
# i=: 4
# i=: 5
# i=: 6
# i=: 7
# i=: 8
# i=: 9
# i=: 10
# i=: 11
# i=: 12
# i=: 13
# i=: 14
# i=: 15
# i=: 16
# i=: 17
# i=: 18
# i=: 19
# i=: 20
# i=: 21
# i=: 22
# i=: 23
# i=: 24
# i=: 25
# i=: 26
# i=: 27
# i=: 28
# i=: 29
# i=: 30
# i=: 31
# i=: 32
# i=: 33
# i=: 34
# i=: 35
# i=: 36
# i=: 37
# i=: 38
# i=: 39
# i=: 40
# i=: 41
# i=: 42
# i=: 43
# i=: 44
# i=: 45
# i=: 46
# i=: 47
# i=: 48
# i=: 49
# i=: 50
# i=: 51
# i=: 52
# i=: 53
# i=: 54
# i=: 55
# i=: 56
# i=: 57
# i=: 58
# i=: 59
# i=: 60
# i=: 61
# i=: 62
# i=: 63
# i=: 64
# i=: 65
# i=: 66
# i=: 67
# i=: 68
# i=: 69
# i=: 70
# i=: 71
# i=: 72
# i=: 73
# i=: 74
# i=: 75
# i=: 76
# i=: 77
# i=: 78
# i=: 79
# i=: 80
# i=: 81
# i=: 82
# i=: 83
# i=: 84
# i=: 85
# i=: 86
# i=: 87
# i=: 88
# i=: 89
# i=: 90
# i=: 91
# i=: 92
# i=: 93
# i=: 94
# i=: 95
# i=: 96
# i=: 97
# i=: 98
# i=: 99
# i=: 100
# i=: 101
# i=: 102
# i=: 103
# i=: 104
# i=: 105
# i=: 106
# i=: 107
# i=: 108
# i=: 109
# i=: 110
# ...

# %%
homequa_china_new = get_cleaned_seg(homequa_china_new)
homequa_china_new.head(), len(homequa_china_new)
# Out:
# (                        TITLE                 TIME CATEGORY  \
#  0           高端60萬劑到位 第六輪23日開打  2021-08-12 04:10:00     財經要聞
#  1                 春節檢疫派員至旅館採檢  2021-12-17 04:10:00     地方新聞
#  2       今增3本土！雙北有兩人 1台籍60歲男死亡  2022-02-25 13:51:00       生活
#  3   入境居檢鬆綁首日 指揮中心：落地採檢陽性率較上周低  2022-03-08 14:59:58       生活
#  4  境外移工確診攀增 侯友宜：國外篩檢報告可不可信待討論  2020-12-07 11:55:47       生活
#
#                                           DESCRIPTION  \
#  0  衛長陳時中11日宣布，第六輪疫苗施打將提供高端接種，23日起開打，疫苗數量至少有60多萬劑，...
#  1  春節檢疫專案14日起跑，因應返鄉者眾，負責居家檢疫的桃園市民政局提出安排採檢、安排移動交通工...
#  2  國內今天新增3例本土個案，皆為新案，包括一名美國境外移入個案的家人，以及一對雙北父子檔確診，...
#  3  隨著新冠肺炎疫情趨緩，昨起入境檢疫天數由14天減至10天。根據中央流行疫情指揮中心統計，昨落...
#  4  境外移工確診個案攀增，新北市長侯友宜今談及歡樂耶誕城防疫措施表示，政府雖規定境外移入者須檢附...
#
#                                               CONTENT             KEYWORDS  \
#  0  衛長陳時中11日宣布，第六輪疫苗施打將提供高端接種，23日起開打，疫苗數量至少有60多萬劑，...      大陸,高端,陳時中,疫苗,檢疫
#  1  春節檢疫專案14日起跑，因應返鄉者眾，負責居家檢疫的桃園市民政局提出安排採檢、安排移動交通工...     採檢,方案,計程車,二階段,檢疫
# ...

# %%
homequa_china_new = homequa_china_new.rename_axis('index').reset_index()
homequa_china_new
# Out:
#       index                           TITLE                 TIME CATEGORY  \
# 0         0               高端60萬劑到位 第六輪23日開打  2021-08-12 04:10:00     財經要聞
# 1         1                     春節檢疫派員至旅館採檢  2021-12-17 04:10:00     地方新聞
# 2         2           今增3本土！雙北有兩人 1台籍60歲男死亡  2022-02-25 13:51:00       生活
# 3         3       入境居檢鬆綁首日 指揮中心：落地採檢陽性率較上周低  2022-03-08 14:59:58       生活
# 4         4      境外移工確診攀增 侯友宜：國外篩檢報告可不可信待討論  2020-12-07 11:55:47       生活
# ...     ...                             ...                  ...      ...
# 2070   2070                  帛琉旅遊泡泡 居檢天數將縮短  2021-03-09 04:10:00     生活新聞
# 2071   2071  春節返鄉 居檢掀搶房大作戰 北高防疫旅館緊急鎖房 限市民入住  2021-01-06 04:10:00     生活新聞
# 2072   2072                  諾富特檢疫客一般客 混居半年  2021-05-02 04:10:00       生活
# 2073   2073     隔離人數暴增至1576人 新北檢疫隔離關懷中心持續擴編  2021-05-18 11:29:15       生活
# 2074   2074         璨樹颱風攪局 指揮中心提醒防疫旅館疏散分流做好  2021-09-11 19:43:38       生活
#
#                                             DESCRIPTION  \
# ...

# %%
homequa_china_new = homequa_china_new[['index', 'TITLE', 'cleaned_text', 'FROM', 'TIME']]
homequa_china_new.columns = ['CATEGORY', 'TITLE', 'cleaned_text', 'FROM', 'TIME']
homequa_china_new
# Out:
#       CATEGORY                           TITLE  \
# 0            0               高端60萬劑到位 第六輪23日開打
# 1            1                     春節檢疫派員至旅館採檢
# 2            2           今增3本土！雙北有兩人 1台籍60歲男死亡
# 3            3       入境居檢鬆綁首日 指揮中心：落地採檢陽性率較上周低
# 4            4      境外移工確診攀增 侯友宜：國外篩檢報告可不可信待討論
# ...        ...                             ...
# 2070      2070                  帛琉旅遊泡泡 居檢天數將縮短
# 2071      2071  春節返鄉 居檢掀搶房大作戰 北高防疫旅館緊急鎖房 限市民入住
# 2072      2072                  諾富特檢疫客一般客 混居半年
# 2073      2073     隔離人數暴增至1576人 新北檢疫隔離關懷中心持續擴編
# 2074      2074         璨樹颱風攪局 指揮中心提醒防疫旅館疏散分流做好
#
#                                            cleaned_text   FROM  \
# 0     高端 劑 輪 日 開打 衛長 陳時中 宣布 輪 疫苗 施打 提供 高端 接種 日 開打 疫苗...  中時新聞網
# 1     春節 檢疫 派員 旅館 採檢 春節 檢疫 專案 日 返鄉 負責 居家 檢疫 桃園市 民政局 ...  中時新聞網
# 2     增 雙北 台籍 歲 男 死亡 國內 新增 例 皆 新案 包括 名 美國 境外 移入 家人 雙...  中時新聞網
# 3     入境 居檢 鬆綁 首日 指揮中心 落地 採檢 陽性率 低 新冠 肺炎 疫情 趨緩 昨 入境 ...  中時新聞網
# 4     境外 移工 確診 攀增 侯友宜 國外 篩檢 報告 信待 討論 境外 移工 確診 攀增 新北 ...  中時新聞網
# ...

# %%
homequa_china_new.to_csv("/Users/lilywang/Library/CloudStorage/OneDrive-臺北醫學大學/畢業專題/資料與程式碼/Reader Emotion(情感分析資料)/中時＋自由/居家檢疫 居檢/中時/居家檢疫_cleaned.csv", header=True, index=False, encoding="utf-8")

# %% [markdown]
# ## 居家檢疫 居檢-自由

# %%
homequarantine_free = pd.read_csv("/Users/lilywang/Library/CloudStorage/OneDrive-臺北醫學大學/畢業專題/資料與程式碼/Reader Emotion(情感分析資料)/中時＋自由/居家檢疫 居檢/自由/居家檢疫.csv", encoding = 'utf-8')
homequarantine_free.head()
# Out:
#                              TITLE                 TIME CATEGORY  \
# 0     民盼打疫苗返台改居家檢疫 陳時中：等疫苗涵蓋率較高再考慮  2021-08-25 16:28:19     life
# 1  西班牙籍丈夫違反居檢挨罰卻離境 士林分署勸說終繳完10萬罰鍰   2021-12-21 12:41:05  society
# 2       2方法確認有無英國旅遊史 指揮中心：隱匿可重罰15萬  2020-12-22 15:32:56     life
# 3        武肺確診個案8例定序中 莊人祥︰加強檢疫防變種病毒  2021-01-04 15:35:53     life
# 4           離譜！高雄防疫旅館爆5男群聚開趴 衛生局開罰  2021-07-22 17:01:31     life
#
#                                          DESCRIPTION  \
# 0  國內武漢肺炎（新型冠狀病毒病，COVID-19）疫苗的人口涵蓋率已達4成，有民眾向本報反映，...
# 1  西班牙籍丈夫違反居家檢疫規定挨罰10萬元，卻未繳罰鍰就先行離境，經法務部行政執行署士林分署向...
# 2  因應國內再度出現武漢肺炎（新型冠狀病毒病，COVID-19）本土病例，中央流行疫情指揮中心今...
# 3  中央流行疫情指揮中心今天公布，針對檢驗Ct值27以下的確診個案、完成18株病毒定序，確認變種...
# 4  5名男子從伊斯坦堡回台，在高雄某防疫旅館居家檢疫期間竟然群聚在同個房間喝酒開趴遭檢舉，高市衛...
#
#                                              CONTENT  FROM  \
# 0  有民眾反映，期盼政府鬆綁在國外打完2劑疫苗的人，返台可在家中以1人1室方式進行居家檢疫，以減...  自由時報
# 1  西班牙籍丈夫違反居檢規定挨罰卻離境，經士林分署人員積極勸說台籍妻子（黑衣），丈夫已於本月分期...  自由時報
# 2  要如何確認有英國旅遊史？指揮中心表示，暫定有2種方式確認。（指揮中心提供）\n〔記者吳亮儀／...  自由時報
# ...

# %%
homequa_free = pd.read_csv("/Users/lilywang/Library/CloudStorage/OneDrive-臺北醫學大學/畢業專題/資料與程式碼/Reader Emotion(情感分析資料)/中時＋自由/居家檢疫 居檢/自由/居檢.csv", encoding = 'utf-8')
homequa_free.head()
# Out:
#                                           TITLE                 TIME CATEGORY  \
# 0                    金門截獲3嫌走私中國香菇 超過24小時後才送居家檢疫  2021-06-19 14:21:48  society
# 1  機師、空姐一律居檢7天 採檢陰性才能進社區／自主管理7天禁搭大眾運輸、不得出入賣場、夜店  2020-12-29 05:30:00     life
# 2                 北市防疫旅館一房難求 觀光局：近期全台會再新增1000間房  2021-01-05 19:15:05     life
# 3                        部桃醫護群聚感染 各大醫院最新管制措施看這裡  2021-01-21 01:08:00     life
# 4                           桃園居隔、居檢逾萬人 聯合關懷中心成立  2021-01-26 05:30:00     life
#
#                                          DESCRIPTION  \
# 0  海巡署金馬澎分署第九岸巡隊今天表示，日前在金沙鎮湖山港岸際截獲3人走私中國香菇774.14公...
# 1  外界檢討航空業防疫聲浪不斷，中央流行疫情指揮中心昨公布，航空機師過去居檢三天、空服員五天的居...
# 2  農曆春節即將到來，不少台商、海外台人趕回家過年，造成台北市等部分縣市防疫旅館一房難求。北市業...
# 3  首次上稿 1/20 09:46更新時間 1/21 01:08衛生福利部桃園醫院近日發生群聚感...
# 4  衛生福利部桃園醫院武漢肺炎（新型冠狀病毒病，COVID-19）群聚感染擴大，已有15例本土確...
#
#                                              CONTENT  FROM  \
# 0  金門岸巡隊著防護衣登小船清查。（金門岸巡隊提供）\n〔記者吳正庭／金門報導〕海巡署金馬澎分署...  自由時報
# ...

# %%
homequa_free_new = pd.concat([homequarantine_free, homequa_free], axis = 0)
homequa_free_new
# Out:
#                                TITLE                 TIME CATEGORY  \
# 0       民盼打疫苗返台改居家檢疫 陳時中：等疫苗涵蓋率較高再考慮  2021-08-25 16:28:19     life
# 1    西班牙籍丈夫違反居檢挨罰卻離境 士林分署勸說終繳完10萬罰鍰   2021-12-21 12:41:05  society
# 2         2方法確認有無英國旅遊史 指揮中心：隱匿可重罰15萬  2020-12-22 15:32:56     life
# 3          武肺確診個案8例定序中 莊人祥︰加強檢疫防變種病毒  2021-01-04 15:35:53     life
# 4             離譜！高雄防疫旅館爆5男群聚開趴 衛生局開罰  2021-07-22 17:01:31     life
# ..                               ...                  ...      ...
# 255          陳修將涉殺死小三獲交保 彰化地院下午重開羈押庭  2021-12-14 12:13:36  society
# 256             嘉義縣+3！1人曾開車北上參加阿妹演唱會  2022-04-19 14:46:16     life
# 257         居檢男4天外出拒繳罰款  透天厝被封才肯吐60萬  2021-07-07 12:01:08     life
# 258             5分鐘如何丟10萬？ 違規居檢男親身示範  2022-02-08 17:25:45  society
# 259  機組員居檢期改7天抱怨陷惡性循環 民航局：會反映給指揮中心參考  2021-02-05 17:39:05     life
#
#                                            DESCRIPTION  \
# 0    國內武漢肺炎（新型冠狀病毒病，COVID-19）疫苗的人口涵蓋率已達4成，有民眾向本報反映，...
# ...

# %%
homequa_free_new = homequa_free_new.rename_axis('index').reset_index()
homequa_free_new = homequa_free_new.drop("index", axis = 1)
homequa_free_new.head()
# Out:
#                              TITLE                 TIME CATEGORY  \
# 0     民盼打疫苗返台改居家檢疫 陳時中：等疫苗涵蓋率較高再考慮  2021-08-25 16:28:19     life
# 1  西班牙籍丈夫違反居檢挨罰卻離境 士林分署勸說終繳完10萬罰鍰   2021-12-21 12:41:05  society
# 2       2方法確認有無英國旅遊史 指揮中心：隱匿可重罰15萬  2020-12-22 15:32:56     life
# 3        武肺確診個案8例定序中 莊人祥︰加強檢疫防變種病毒  2021-01-04 15:35:53     life
# 4           離譜！高雄防疫旅館爆5男群聚開趴 衛生局開罰  2021-07-22 17:01:31     life
#
#                                          DESCRIPTION  \
# 0  國內武漢肺炎（新型冠狀病毒病，COVID-19）疫苗的人口涵蓋率已達4成，有民眾向本報反映，...
# 1  西班牙籍丈夫違反居家檢疫規定挨罰10萬元，卻未繳罰鍰就先行離境，經法務部行政執行署士林分署向...
# 2  因應國內再度出現武漢肺炎（新型冠狀病毒病，COVID-19）本土病例，中央流行疫情指揮中心今...
# 3  中央流行疫情指揮中心今天公布，針對檢驗Ct值27以下的確診個案、完成18株病毒定序，確認變種...
# 4  5名男子從伊斯坦堡回台，在高雄某防疫旅館居家檢疫期間竟然群聚在同個房間喝酒開趴遭檢舉，高市衛...
#
#                                              CONTENT  FROM  \
# 0  有民眾反映，期盼政府鬆綁在國外打完2劑疫苗的人，返台可在家中以1人1室方式進行居家檢疫，以減...  自由時報
# 1  西班牙籍丈夫違反居檢規定挨罰卻離境，經士林分署人員積極勸說台籍妻子（黑衣），丈夫已於本月分期...  自由時報
# 2  要如何確認有英國旅遊史？指揮中心表示，暫定有2種方式確認。（指揮中心提供）\n〔記者吳亮儀／...  自由時報
# ...

# %%
from monpa import utils

homequa_free_new.fillna('',inplace=True)

for i in range(len(homequa_free_new)):
    result = []
    for item in utils.short_sentence(homequa_free_new.loc[i,'TITLE'] + homequa_free_new.loc[i,'CONTENT']):
        if item:
            result.append(monpa.cut(item))

    tmp_result =""
    for k in range(len(result)):
        tmp_result += " ".join(result[k])
    homequa_free_new.loc[i,'cut_text'] = tmp_result
    print('i=:',i)
    #break

homequa_free_new.head(), len(homequa_free_new)
# Out:
# i=: 0
# i=: 1
# i=: 2
# i=: 3
# i=: 4
# i=: 5
# i=: 6
# i=: 7
# i=: 8
# i=: 9
# i=: 10
# i=: 11
# i=: 12
# i=: 13
# i=: 14
# i=: 15
# i=: 16
# i=: 17
# i=: 18
# i=: 19
# i=: 20
# i=: 21
# i=: 22
# i=: 23
# i=: 24
# i=: 25
# i=: 26
# i=: 27
# i=: 28
# i=: 29
# i=: 30
# i=: 31
# i=: 32
# i=: 33
# i=: 34
# i=: 35
# i=: 36
# i=: 37
# i=: 38
# i=: 39
# i=: 40
# i=: 41
# i=: 42
# i=: 43
# i=: 44
# i=: 45
# i=: 46
# i=: 47
# i=: 48
# i=: 49
# i=: 50
# i=: 51
# i=: 52
# i=: 53
# i=: 54
# i=: 55
# i=: 56
# i=: 57
# i=: 58
# i=: 59
# i=: 60
# i=: 61
# i=: 62
# i=: 63
# i=: 64
# i=: 65
# i=: 66
# i=: 67
# i=: 68
# i=: 69
# i=: 70
# i=: 71
# i=: 72
# i=: 73
# i=: 74
# i=: 75
# i=: 76
# i=: 77
# i=: 78
# i=: 79
# i=: 80
# i=: 81
# i=: 82
# i=: 83
# i=: 84
# i=: 85
# i=: 86
# i=: 87
# i=: 88
# i=: 89
# i=: 90
# i=: 91
# i=: 92
# i=: 93
# i=: 94
# i=: 95
# i=: 96
# i=: 97
# i=: 98
# i=: 99
# i=: 100
# i=: 101
# i=: 102
# i=: 103
# i=: 104
# i=: 105
# i=: 106
# i=: 107
# i=: 108
# i=: 109
# i=: 110
# ...

# %%
homequa_free_new = get_cleaned_seg(homequa_free_new)
homequa_free_new.head(), len(homequa_free_new)
# Out:
# (                             TITLE                 TIME CATEGORY  \
#  0     民盼打疫苗返台改居家檢疫 陳時中：等疫苗涵蓋率較高再考慮  2021-08-25 16:28:19     life
#  1  西班牙籍丈夫違反居檢挨罰卻離境 士林分署勸說終繳完10萬罰鍰   2021-12-21 12:41:05  society
#  2       2方法確認有無英國旅遊史 指揮中心：隱匿可重罰15萬  2020-12-22 15:32:56     life
#  3        武肺確診個案8例定序中 莊人祥︰加強檢疫防變種病毒  2021-01-04 15:35:53     life
#  4           離譜！高雄防疫旅館爆5男群聚開趴 衛生局開罰  2021-07-22 17:01:31     life
#
#                                           DESCRIPTION  \
#  0  國內武漢肺炎（新型冠狀病毒病，COVID-19）疫苗的人口涵蓋率已達4成，有民眾向本報反映，...
#  1  西班牙籍丈夫違反居家檢疫規定挨罰10萬元，卻未繳罰鍰就先行離境，經法務部行政執行署士林分署向...
#  2  因應國內再度出現武漢肺炎（新型冠狀病毒病，COVID-19）本土病例，中央流行疫情指揮中心今...
#  3  中央流行疫情指揮中心今天公布，針對檢驗Ct值27以下的確診個案、完成18株病毒定序，確認變種...
#  4  5名男子從伊斯坦堡回台，在高雄某防疫旅館居家檢疫期間竟然群聚在同個房間喝酒開趴遭檢舉，高市衛...
#
#                                               CONTENT  FROM  \
#  0  有民眾反映，期盼政府鬆綁在國外打完2劑疫苗的人，返台可在家中以1人1室方式進行居家檢疫，以減...  自由時報
#  1  西班牙籍丈夫違反居檢規定挨罰卻離境，經士林分署人員積極勸說台籍妻子（黑衣），丈夫已於本月分期...  自由時報
# ...

# %%
homequa_free_new = homequa_free_new.rename_axis('index').reset_index()
homequa_free_new
# Out:
#      index                            TITLE                 TIME CATEGORY  \
# 0        0     民盼打疫苗返台改居家檢疫 陳時中：等疫苗涵蓋率較高再考慮  2021-08-25 16:28:19     life
# 1        1  西班牙籍丈夫違反居檢挨罰卻離境 士林分署勸說終繳完10萬罰鍰   2021-12-21 12:41:05  society
# 2        2       2方法確認有無英國旅遊史 指揮中心：隱匿可重罰15萬  2020-12-22 15:32:56     life
# 3        3        武肺確診個案8例定序中 莊人祥︰加強檢疫防變種病毒  2021-01-04 15:35:53     life
# 4        4           離譜！高雄防疫旅館爆5男群聚開趴 衛生局開罰  2021-07-22 17:01:31     life
# ..     ...                              ...                  ...      ...
# 980    980          陳修將涉殺死小三獲交保 彰化地院下午重開羈押庭  2021-12-14 12:13:36  society
# 981    981             嘉義縣+3！1人曾開車北上參加阿妹演唱會  2022-04-19 14:46:16     life
# 982    982         居檢男4天外出拒繳罰款  透天厝被封才肯吐60萬  2021-07-07 12:01:08     life
# 983    983             5分鐘如何丟10萬？ 違規居檢男親身示範  2022-02-08 17:25:45  society
# 984    984  機組員居檢期改7天抱怨陷惡性循環 民航局：會反映給指揮中心參考  2021-02-05 17:39:05     life
#
#                                            DESCRIPTION  \
# ...

# %%
homequa_free_new = homequa_free_new[['index', 'TITLE', 'cleaned_text', 'FROM', 'TIME']]
homequa_free_new.columns = ['CATEGORY', 'TITLE', 'cleaned_text', 'FROM', 'TIME']
homequa_free_new
# Out:
#      CATEGORY                            TITLE  \
# 0           0     民盼打疫苗返台改居家檢疫 陳時中：等疫苗涵蓋率較高再考慮
# 1           1  西班牙籍丈夫違反居檢挨罰卻離境 士林分署勸說終繳完10萬罰鍰
# 2           2       2方法確認有無英國旅遊史 指揮中心：隱匿可重罰15萬
# 3           3        武肺確診個案8例定序中 莊人祥︰加強檢疫防變種病毒
# 4           4           離譜！高雄防疫旅館爆5男群聚開趴 衛生局開罰
# ..        ...                              ...
# 980       980          陳修將涉殺死小三獲交保 彰化地院下午重開羈押庭
# 981       981             嘉義縣+3！1人曾開車北上參加阿妹演唱會
# 982       982         居檢男4天外出拒繳罰款  透天厝被封才肯吐60萬
# 983       983             5分鐘如何丟10萬？ 違規居檢男親身示範
# 984       984  機組員居檢期改7天抱怨陷惡性循環 民航局：會反映給指揮中心參考
#
#                                           cleaned_text  FROM  \
# 0    民盼 疫苗 返 台 改 居家 檢疫 陳時中 疫苗 涵蓋率 高 考慮 民眾 反映 期盼 政府 ...  自由時報
# 1    西班牙籍 丈夫 違反 居檢 挨罰 士林 分署 勸說 終 繳完 罰鍰 西班 牙籍 丈夫 違反 ...  自由時報
# 2    方法 確認 英國 旅遊史 指揮中心 隱匿 重罰 確認 英國 旅遊史 指揮中心 表示 暫定 方...  自由時報
# 3    武肺 確 診 例 定序 莊人祥 ︰ 加強 檢疫 防 變種 病毒 莊人祥 表示 變種 病毒 侵...  自由時報
# 4    高雄 防疫 旅館 爆 男 群聚 開 趴 衛生局 開罰 高雄 市長 陳其邁 證實 違規 開罰 ...  自由時報
# ...

# %%
homequa_free_new.to_csv("/Users/lilywang/Library/CloudStorage/OneDrive-臺北醫學大學/畢業專題/資料與程式碼/Reader Emotion(情感分析資料)/中時＋自由/居家檢疫 居檢/自由/居家檢疫_cleaned.csv", header=True, index=False, encoding="utf-8")
